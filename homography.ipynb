# %% [markdown]
# # Dependendies

# %%
from ultralytics import YOLO
from IPython.display import display, Image
from dotenv import load_dotenv
import numpy as np
import cv2
import os

# %% [markdown]
# # Court Detection

# %% [markdown]
# ## Model Setup

# %%
MODEL = "yolov8c.pt"
COURT_DIR = "models/yolo/court"

# %% [markdown]
# ### Test Model

# %%
OUTPUT_DIR = "models/yolo/custom"
TEST_VIDEO = "data/yolo/video.mp4"

# %%
test_command = f"yolo track model='models/yolo/{MODEL}' source={TEST_VIDEO} project={OUTPUT_DIR} conf=0.01"
os.system(test_command)
# Out:
# Ultralytics YOLOv8.0.203 🚀 Python-3.9.18 torch-2.1.0 CPU (Apple M1 Max)
# Model summary (fused): 268 layers, 68127420 parameters, 0 gradients, 257.4 GFLOPs
#
# video 1/1 (1/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 237.8ms
# video 1/1 (2/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 227.6ms
# video 1/1 (3/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 223.7ms
# video 1/1 (4/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 224.5ms
# video 1/1 (5/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 220.0ms
# video 1/1 (6/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 230.4ms
# video 1/1 (7/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 228.9ms
# video 1/1 (8/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 228.1ms
# video 1/1 (9/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 225.4ms
# video 1/1 (10/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 228.5ms
# video 1/1 (11/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 227.7ms
# video 1/1 (12/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 225.6ms
# video 1/1 (13/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 225.8ms
# video 1/1 (14/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 226.6ms
# video 1/1 (15/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 224.0ms
# video 1/1 (16/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 224.7ms
# video 1/1 (17/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 225.0ms
# video 1/1 (18/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 222.8ms
# video 1/1 (19/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 225.6ms
# video 1/1 (20/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 226.3ms
# video 1/1 (21/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 222.6ms
# video 1/1 (22/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 220.5ms
# video 1/1 (23/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 223.3ms
# video 1/1 (24/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 219.7ms
# video 1/1 (25/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 216.3ms
# video 1/1 (26/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 219.2ms
# video 1/1 (27/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 217.0ms
# video 1/1 (28/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 220.2ms
# video 1/1 (29/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 218.2ms
# video 1/1 (30/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 218.2ms
# video 1/1 (31/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 218.3ms
# video 1/1 (32/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 219.1ms
# video 1/1 (33/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 223.9ms
# video 1/1 (34/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 227.1ms
# video 1/1 (35/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 224.3ms
# video 1/1 (36/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 223.9ms
# video 1/1 (37/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 219.6ms
# video 1/1 (38/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 227.5ms
# video 1/1 (39/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 228.0ms
# video 1/1 (40/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 225.2ms
# video 1/1 (41/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 250.5ms
# video 1/1 (42/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 224.5ms
# video 1/1 (43/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 222.8ms
# video 1/1 (44/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 222.4ms
# video 1/1 (45/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 220.8ms
# video 1/1 (46/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 219.8ms
# video 1/1 (47/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 225.5ms
# video 1/1 (48/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 226.7ms
# video 1/1 (49/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 225.7ms
# video 1/1 (50/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 224.1ms
# video 1/1 (51/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 223.8ms
# video 1/1 (52/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 222.0ms
# video 1/1 (53/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 225.0ms
# video 1/1 (54/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 220.3ms
# video 1/1 (55/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 220.8ms
# video 1/1 (56/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 222.6ms
# video 1/1 (57/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 221.7ms
# video 1/1 (58/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 223.1ms
# video 1/1 (59/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 225.4ms
# video 1/1 (60/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 221.3ms
# video 1/1 (61/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 235.5ms
# video 1/1 (62/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 222.0ms
# video 1/1 (63/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 226.5ms
# video 1/1 (64/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 218.5ms
# video 1/1 (65/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 224.1ms
# video 1/1 (66/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 219.6ms
# video 1/1 (67/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 218.5ms
# video 1/1 (68/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 219.1ms
# video 1/1 (69/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 220.9ms
# video 1/1 (70/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 1 Middle, 4 Paints, 1 Tick, 218.9ms
# video 1/1 (71/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 1 Middle, 4 Paints, 1 Tick, 221.3ms
# video 1/1 (72/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 1 Middle, 4 Paints, 222.8ms
# video 1/1 (73/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 1 Middle, 4 Paints, 223.6ms
# video 1/1 (74/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 1 Middle, 4 Paints, 219.1ms
# video 1/1 (75/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 1 Middle, 4 Paints, 219.8ms
# video 1/1 (76/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 1 Middle, 4 Paints, 1 Tick, 226.8ms
# video 1/1 (77/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 1 Middle, 4 Paints, 1 Tick, 220.2ms
# video 1/1 (78/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 1 Middle, 4 Paints, 1 Tick, 218.5ms
# video 1/1 (79/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 1 Middle, 4 Paints, 1 Tick, 222.7ms
# video 1/1 (80/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 1 Middle, 4 Paints, 1 Tick, 224.3ms
# video 1/1 (81/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 1 Middle, 4 Paints, 1 Tick, 223.3ms
# video 1/1 (82/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 1 Middle, 4 Paints, 1 Tick, 223.4ms
# video 1/1 (83/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 1 Middle, 4 Paints, 1 Tick, 221.8ms
# video 1/1 (84/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 1 Middle, 4 Paints, 223.2ms
# video 1/1 (85/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 1 Middle, 4 Paints, 223.6ms
# video 1/1 (86/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 1 Middle, 4 Paints, 221.1ms
# video 1/1 (87/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 1 Middle, 3 Paints, 219.9ms
# video 1/1 (88/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 1 Middle, 3 Paints, 220.5ms
# video 1/1 (89/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 1 Middle, 3 Paints, 224.9ms
# video 1/1 (90/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 1 Middle, 3 Paints, 220.6ms
# video 1/1 (91/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Middle, 2 Paints, 216.9ms
# video 1/1 (92/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Middle, 2 Paints, 219.8ms
# video 1/1 (93/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Middle, 2 Paints, 221.1ms
# video 1/1 (94/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Middle, 2 Paints, 221.1ms
# video 1/1 (95/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 2 Paints, 220.1ms
# video 1/1 (96/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 2 Paints, 220.7ms
# video 1/1 (97/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 2 Paints, 1 Tick, 228.2ms
# video 1/1 (98/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Paint, 1 Tick, 220.9ms
# video 1/1 (99/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Tick, 225.2ms
# video 1/1 (100/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Tick, 221.5ms
# video 1/1 (101/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Tick, 223.5ms
# video 1/1 (102/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Tick, 225.2ms
# video 1/1 (103/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Tick, 226.2ms
# video 1/1 (104/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Paint, 1 Tick, 220.9ms
# video 1/1 (105/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 1 Paint, 1 Tick, 223.7ms
# video 1/1 (106/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 1 Paint, 224.2ms
# video 1/1 (107/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 1 Paint, 221.2ms
# video 1/1 (108/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 1 Paint, 224.0ms
# video 1/1 (109/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 3 Paints, 223.2ms
# video 1/1 (110/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 3 Paints, 222.1ms
# video 1/1 (111/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 3 Paints, 224.3ms
# video 1/1 (112/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 3 Paints, 222.8ms
# video 1/1 (113/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 3 Paints, 224.1ms
# video 1/1 (114/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 3 Paints, 221.0ms
# video 1/1 (115/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 3 Paints, 219.8ms
# video 1/1 (116/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 3 Paints, 220.1ms
# video 1/1 (117/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 3 Paints, 222.5ms
# video 1/1 (118/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 3 Paints, 1 Tick, 245.7ms
# video 1/1 (119/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 3 Paints, 1 Tick, 226.3ms
# video 1/1 (120/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 3 Paints, 1 Tick, 222.4ms
# video 1/1 (121/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 3 Paints, 1 Tick, 221.0ms
# video 1/1 (122/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 3 Paints, 1 Tick, 222.5ms
# Speed: 1.1ms preprocess, 223.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to models/yolo/custom/predict6
# 💡 Learn more at https://docs.ultralytics.com/modes/track
# 0

# %% [markdown]
# ## Extract Court Data

# %%
model = YOLO(f"models/yolo/{MODEL}")
results = model.track(source="data/yolo/video.mp4", project=f"{COURT_DIR}", conf=0.1, stream=True, show=True)

# %% [markdown]
# ### View Results

# %% [markdown]
# #### Class Mappings
# |  Class  | Number |
# |---------|--------|
# | Corner  | 0      |
# | Middle  | 1      |
# | Paint   | 2      |
# | Tick    | 3      |
#
# #### Tensor Formats
# `data`: `[top left x, top left y, width, height, tracking id, confidence, class]`

# %%
classes = ["corner", "middle", "paint", "tick"]

# %%
for r in results:
    boxes = r.boxes
    print(boxes)
# Out:
# video 1/1 (1/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 269.6ms
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0., 3., 2., 2., 2., 2.])
# conf: tensor([0.7586, 0.7529, 0.7290, 0.7056, 0.6977, 0.6976])
# data: tensor([[8.0418e+02, 2.7150e+02, 8.4947e+02, 3.0859e+02, 1.0000e+00, 7.5858e-01, 0.0000e+00],
#         [3.9865e+02, 2.9968e+02, 4.3090e+02, 3.3680e+02, 2.0000e+00, 7.5287e-01, 3.0000e+00],
#         [6.5945e+02, 4.6991e+02, 6.9909e+02, 5.0534e+02, 3.0000e+00, 7.2903e-01, 2.0000e+00],
#         [9.9259e+02, 4.3996e+02, 1.0348e+03, 4.7898e+02, 4.0000e+00, 7.0565e-01, 2.0000e+00],
#         [5.9816e+02, 3.7945e+02, 6.3980e+02, 4.1230e+02, 5.0000e+00, 6.9766e-01, 2.0000e+00],
#         [8.9795e+02, 3.5401e+02, 9.3412e+02, 3.8633e+02, 6.0000e+00, 6.9758e-01, 2.0000e+00]])
# id: tensor([1., 2., 3., 4., 5., 6.])
# is_track: True
# orig_shape: (720, 1280)
# shape: torch.Size([6, 7])
# xywh: tensor([[ 826.8217,  290.0423,   45.2891,   37.0865],
#         [ 414.7773,  318.2394,   32.2549,   37.1146],
#         [ 679.2688,  487.6269,   39.6343,   35.4288],
#         [1013.7064,  459.4719,   42.2317,   39.0251],
#         [ 618.9800,  395.8744,   41.6326,   32.8511],
#         [ 916.0360,  370.1706,   36.1738,   32.3171]])
# xywhn: tensor([[0.6460, 0.4028, 0.0354, 0.0515],
#         [0.3240, 0.4420, 0.0252, 0.0515],
#         [0.5307, 0.6773, 0.0310, 0.0492],
#         [0.7920, 0.6382, 0.0330, 0.0542],
#         [0.4836, 0.5498, 0.0325, 0.0456],
#         [0.7157, 0.5141, 0.0283, 0.0449]])
# xyxy: tensor([[ 804.1771,  271.4990,  849.4662,  308.5855],
#         [ 398.6498,  299.6821,  430.9047,  336.7968],
#         [ 659.4517,  469.9125,  699.0859,  505.3413],
#         [ 992.5906,  439.9593, 1034.8223,  478.9845],
#         [ 598.1637,  379.4489,  639.7963,  412.3000],
#         [ 897.9491,  354.0120,  934.1229,  386.3292]])
# xyxyn: tensor([[0.6283, 0.3771, 0.6636, 0.4286],
#         [0.3114, 0.4162, 0.3366, 0.4678],
#         [0.5152, 0.6527, 0.5462, 0.7019],
#         [0.7755, 0.6111, 0.8085, 0.6653],
#         [0.4673, 0.5270, 0.4998, 0.5726],
#         [0.7015, 0.4917, 0.7298, 0.5366]])
# video 1/1 (2/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 234.5ms
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0., 2., 2., 2., 2., 3.])
# conf: tensor([0.7561, 0.7329, 0.7095, 0.7050, 0.6995, 0.6845])
# data: tensor([[8.0398e+02, 2.7149e+02, 8.4958e+02, 3.0858e+02, 1.0000e+00, 7.5606e-01, 0.0000e+00],
#         [6.5920e+02, 4.6971e+02, 6.9827e+02, 5.0558e+02, 2.0000e+00, 7.3288e-01, 2.0000e+00],
#         [9.9219e+02, 4.3988e+02, 1.0345e+03, 4.7897e+02, 3.0000e+00, 7.0954e-01, 2.0000e+00],
#         [8.9773e+02, 3.5390e+02, 9.3388e+02, 3.8627e+02, 4.0000e+00, 7.0503e-01, 2.0000e+00],
#         [5.9823e+02, 3.8012e+02, 6.3896e+02, 4.1293e+02, 5.0000e+00, 6.9947e-01, 2.0000e+00],
#         [3.9393e+02, 2.9898e+02, 4.3079e+02, 3.3682e+02, 6.0000e+00, 6.8449e-01, 3.0000e+00]])
# id: tensor([1., 2., 3., 4., 5., 6.])
# is_track: True
# orig_shape: (720, 1280)
# shape: torch.Size([6, 7])
# xywh: tensor([[ 826.7805,  290.0338,   45.6013,   37.0963],
#         [ 678.7357,  487.6482,   39.0631,   35.8735],
#         [1013.3273,  459.4228,   42.2793,   39.0876],
#         [ 915.8062,  370.0841,   36.1438,   32.3757],
#         [ 618.5948,  396.5245,   40.7241,   32.8068],
#         [ 412.3613,  317.9003,   36.8542,   37.8361]])
# xywhn: tensor([[0.6459, 0.4028, 0.0356, 0.0515],
#         [0.5303, 0.6773, 0.0305, 0.0498],
#         [0.7917, 0.6381, 0.0330, 0.0543],
#         [0.7155, 0.5140, 0.0282, 0.0450],
#         [0.4833, 0.5507, 0.0318, 0.0456],
#         [0.3222, 0.4415, 0.0288, 0.0526]])
# xyxy: tensor([[ 803.9799,  271.4857,  849.5812,  308.5820],
#         [ 659.2042,  469.7114,  698.2673,  505.5850],
#         [ 992.1876,  439.8790, 1034.4669,  478.9666],
#         [ 897.7343,  353.8962,  933.8781,  386.2720],
#         [ 598.2328,  380.1211,  638.9569,  412.9279],
#         [ 393.9342,  298.9822,  430.7885,  336.8184]])
# xyxyn: tensor([[0.6281, 0.3771, 0.6637, 0.4286],
#         [0.5150, 0.6524, 0.5455, 0.7022],
#         [0.7751, 0.6109, 0.8082, 0.6652],
#         [0.7014, 0.4915, 0.7296, 0.5365],
#         [0.4674, 0.5279, 0.4992, 0.5735],
#         [0.3078, 0.4153, 0.3366, 0.4678]])
# video 1/1 (3/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 236.4ms
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0., 2., 2., 2., 2.])
# conf: tensor([0.7580, 0.7319, 0.7102, 0.7062, 0.7024])
# data: tensor([[8.0418e+02, 2.7146e+02, 8.4948e+02, 3.0859e+02, 1.0000e+00, 7.5799e-01, 0.0000e+00],
#         [6.5918e+02, 4.6984e+02, 6.9816e+02, 5.0548e+02, 2.0000e+00, 7.3187e-01, 2.0000e+00],
#         [9.9238e+02, 4.4006e+02, 1.0344e+03, 4.7889e+02, 3.0000e+00, 7.1016e-01, 2.0000e+00],
#         [8.9783e+02, 3.5397e+02, 9.3387e+02, 3.8629e+02, 4.0000e+00, 7.0617e-01, 2.0000e+00],
#         [5.9766e+02, 3.8004e+02, 6.3811e+02, 4.1310e+02, 5.0000e+00, 7.0239e-01, 2.0000e+00]])
# id: tensor([1., 2., 3., 4., 5.])
# is_track: True
# orig_shape: (720, 1280)
# shape: torch.Size([5, 7])
# xywh: tensor([[ 826.8278,  290.0233,   45.2998,   37.1238],
#         [ 678.6693,  487.6586,   38.9736,   35.6338],
#         [1013.3933,  459.4774,   42.0254,   38.8339],
#         [ 915.8489,  370.1303,   36.0388,   32.3179],
#         [ 617.8840,  396.5713,   40.4576,   33.0533]])
# xywhn: tensor([[0.6460, 0.4028, 0.0354, 0.0516],
#         [0.5302, 0.6773, 0.0304, 0.0495],
#         [0.7917, 0.6382, 0.0328, 0.0539],
#         [0.7155, 0.5141, 0.0282, 0.0449],
#         [0.4827, 0.5508, 0.0316, 0.0459]])
# xyxy: tensor([[ 804.1779,  271.4614,  849.4777,  308.5852],
#         [ 659.1825,  469.8417,  698.1561,  505.4755],
#         [ 992.3806,  440.0604, 1034.4060,  478.8943],
#         [ 897.8295,  353.9714,  933.8683,  386.2893],
#         [ 597.6552,  380.0446,  638.1128,  413.0980]])
# xyxyn: tensor([[0.6283, 0.3770, 0.6637, 0.4286],
#         [0.5150, 0.6526, 0.5454, 0.7020],
#         [0.7753, 0.6112, 0.8081, 0.6651],
#         [0.7014, 0.4916, 0.7296, 0.5365],
#         [0.4669, 0.5278, 0.4985, 0.5737]])
# video 1/1 (4/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 235.3ms
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0., 2., 2., 2., 2.])
# conf: tensor([0.7560, 0.7314, 0.7160, 0.7105, 0.7073])
# data: tensor([[8.0377e+02, 2.7129e+02, 8.4963e+02, 3.0885e+02, 1.0000e+00, 7.5600e-01, 0.0000e+00],
#         [6.5929e+02, 4.6984e+02, 6.9844e+02, 5.0546e+02, 2.0000e+00, 7.3139e-01, 2.0000e+00],
#         [8.9730e+02, 3.5378e+02, 9.3329e+02, 3.8628e+02, 3.0000e+00, 7.1596e-01, 2.0000e+00],
#         [5.9685e+02, 3.7936e+02, 6.3833e+02, 4.1342e+02, 4.0000e+00, 7.1053e-01, 2.0000e+00],
#         [9.9214e+02, 4.4011e+02, 1.0344e+03, 4.7902e+02, 5.0000e+00, 7.0730e-01, 2.0000e+00]])
# id: tensor([1., 2., 3., 4., 5.])
# is_track: True
# orig_shape: (720, 1280)
# shape: torch.Size([5, 7])
# xywh: tensor([[ 826.7015,  290.0668,   45.8550,   37.5578],
#         [ 678.8633,  487.6509,   39.1534,   35.6248],
#         [ 915.2964,  370.0262,   35.9944,   32.5021],
#         [ 617.5914,  396.3903,   41.4851,   34.0587],
#         [1013.2860,  459.5643,   42.2822,   38.9158]])
# xywhn: tensor([[0.6459, 0.4029, 0.0358, 0.0522],
#         [0.5304, 0.6773, 0.0306, 0.0495],
#         [0.7151, 0.5139, 0.0281, 0.0451],
#         [0.4825, 0.5505, 0.0324, 0.0473],
#         [0.7916, 0.6383, 0.0330, 0.0540]])
# xyxy: tensor([[ 803.7740,  271.2879,  849.6290,  308.8457],
#         [ 659.2866,  469.8385,  698.4401,  505.4633],
#         [ 897.2992,  353.7752,  933.2936,  386.2773],
#         [ 596.8489,  379.3610,  638.3340,  413.4197],
#         [ 992.1449,  440.1064, 1034.4271,  479.0222]])
# xyxyn: tensor([[0.6279, 0.3768, 0.6638, 0.4290],
#         [0.5151, 0.6526, 0.5457, 0.7020],
#         [0.7010, 0.4914, 0.7291, 0.5365],
#         [0.4663, 0.5269, 0.4987, 0.5742],
#         [0.7751, 0.6113, 0.8081, 0.6653]])
# video 1/1 (5/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 236.8ms
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0., 2., 2., 2., 2., 3.])
# conf: tensor([0.7570, 0.7354, 0.7174, 0.7133, 0.7088, 0.6151])
# data: tensor([[8.0386e+02, 2.7131e+02, 8.4977e+02, 3.0885e+02, 1.0000e+00, 7.5697e-01, 0.0000e+00],
#         [6.5928e+02, 4.6978e+02, 6.9818e+02, 5.0557e+02, 2.0000e+00, 7.3542e-01, 2.0000e+00],
#         [8.9738e+02, 3.5387e+02, 9.3320e+02, 3.8624e+02, 3.0000e+00, 7.1738e-01, 2.0000e+00],
#         [5.9641e+02, 3.7830e+02, 6.3760e+02, 4.1287e+02, 4.0000e+00, 7.1326e-01, 2.0000e+00],
#         [9.9206e+02, 4.4018e+02, 1.0342e+03, 4.7900e+02, 5.0000e+00, 7.0880e-01, 2.0000e+00],
#         [4.0667e+02, 2.9647e+02, 4.4856e+02, 3.4020e+02, 6.0000e+00, 6.1513e-01, 3.0000e+00]])
# id: tensor([1., 2., 3., 4., 5., 6.])
# is_track: True
# orig_shape: (720, 1280)
# shape: torch.Size([6, 7])
# xywh: tensor([[ 826.8164,  290.0798,   45.9084,   37.5482],
#         [ 678.7346,  487.6781,   38.9006,   35.7881],
#         [ 915.2894,  370.0577,   35.8235,   32.3656],
#         [ 617.0090,  395.5842,   41.1881,   34.5670],
#         [1013.1370,  459.5921,   42.1539,   38.8234],
#         [ 427.6158,  318.3351,   41.8817,   43.7371]])
# xywhn: tensor([[0.6460, 0.4029, 0.0359, 0.0522],
#         [0.5303, 0.6773, 0.0304, 0.0497],
#         [0.7151, 0.5140, 0.0280, 0.0450],
#         [0.4820, 0.5494, 0.0322, 0.0480],
#         [0.7915, 0.6383, 0.0329, 0.0539],
#         [0.3341, 0.4421, 0.0327, 0.0607]])
# xyxy: tensor([[ 803.8622,  271.3057,  849.7706,  308.8539],
#         [ 659.2842,  469.7841,  698.1849,  505.5721],
#         [ 897.3776,  353.8749,  933.2011,  386.2405],
#         [ 596.4149,  378.3007,  637.6030,  412.8677],
#         [ 992.0601,  440.1805, 1034.2140,  479.0038],
#         [ 406.6750,  296.4665,  448.5567,  340.2036]])
# xyxyn: tensor([[0.6280, 0.3768, 0.6639, 0.4290],
#         [0.5151, 0.6525, 0.5455, 0.7022],
#         [0.7011, 0.4915, 0.7291, 0.5364],
#         [0.4659, 0.5254, 0.4981, 0.5734],
#         [0.7750, 0.6114, 0.8080, 0.6653],
#         [0.3177, 0.4118, 0.3504, 0.4725]])
# video 1/1 (6/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 235.9ms
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0., 2., 2., 2., 2., 3.])
# conf: tensor([0.7569, 0.7363, 0.7220, 0.7189, 0.7104, 0.6462])
# data: tensor([[8.0383e+02, 2.7110e+02, 8.4978e+02, 3.0904e+02, 1.0000e+00, 7.5690e-01, 0.0000e+00],
#         [6.5911e+02, 4.6971e+02, 6.9833e+02, 5.0569e+02, 2.0000e+00, 7.3625e-01, 2.0000e+00],
#         [8.9740e+02, 3.5389e+02, 9.3293e+02, 3.8624e+02, 3.0000e+00, 7.2203e-01, 2.0000e+00],
#         [5.9568e+02, 3.7842e+02, 6.3690e+02, 4.1279e+02, 4.0000e+00, 7.1893e-01, 2.0000e+00],
#         [9.9183e+02, 4.4005e+02, 1.0342e+03, 4.7906e+02, 5.0000e+00, 7.1045e-01, 2.0000e+00],
#         [3.9818e+02, 2.9576e+02, 4.3823e+02, 3.4091e+02, 6.0000e+00, 6.4625e-01, 3.0000e+00]])
# id: tensor([1., 2., 3., 4., 5., 6.])
# is_track: True
# orig_shape: (720, 1280)
# shape: torch.Size([6, 7])
# xywh: tensor([[ 826.8079,  290.0698,   45.9490,   37.9487],
#         [ 678.7206,  487.6988,   39.2224,   35.9767],
#         [ 915.1654,  370.0626,   35.5291,   32.3476],
#         [ 616.2930,  395.6031,   41.2206,   34.3694],
#         [1013.0020,  459.5512,   42.3340,   39.0103],
#         [ 418.2043,  318.3318,   40.0430,   45.1520]])
# xywhn: tensor([[0.6459, 0.4029, 0.0359, 0.0527],
#         [0.5303, 0.6774, 0.0306, 0.0500],
#         [0.7150, 0.5140, 0.0278, 0.0449],
#         [0.4815, 0.5494, 0.0322, 0.0477],
#         [0.7914, 0.6383, 0.0331, 0.0542],
#         [0.3267, 0.4421, 0.0313, 0.0627]])
# xyxy: tensor([[ 803.8334,  271.0955,  849.7823,  309.0441],
#         [ 659.1094,  469.7104,  698.3318,  505.6872],
#         [ 897.4009,  353.8888,  932.9299,  386.2364],
#         [ 595.6827,  378.4184,  636.9033,  412.7878],
#         [ 991.8350,  440.0461, 1034.1689,  479.0563],
#         [ 398.1828,  295.7557,  438.2258,  340.9078]])
# xyxyn: tensor([[0.6280, 0.3765, 0.6639, 0.4292],
#         [0.5149, 0.6524, 0.5456, 0.7023],
#         [0.7011, 0.4915, 0.7289, 0.5364],
#         [0.4654, 0.5256, 0.4976, 0.5733],
#         [0.7749, 0.6112, 0.8079, 0.6654],
#         [0.3111, 0.4108, 0.3424, 0.4735]])
# video 1/1 (7/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 235.9ms
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0., 2., 2., 2., 2.])
# conf: tensor([0.7583, 0.7367, 0.7163, 0.7142, 0.7085])
# data: tensor([[8.0408e+02, 2.7093e+02, 8.4991e+02, 3.0919e+02, 1.0000e+00, 7.5829e-01, 0.0000e+00],
#         [6.5880e+02, 4.6977e+02, 6.9832e+02, 5.0570e+02, 2.0000e+00, 7.3673e-01, 2.0000e+00],
#         [8.9726e+02, 3.5384e+02, 9.3275e+02, 3.8613e+02, 3.0000e+00, 7.1633e-01, 2.0000e+00],
#         [5.9505e+02, 3.7879e+02, 6.3626e+02, 4.1243e+02, 4.0000e+00, 7.1420e-01, 2.0000e+00],
#         [9.9186e+02, 4.4017e+02, 1.0341e+03, 4.7900e+02, 5.0000e+00, 7.0847e-01, 2.0000e+00]])
# id: tensor([1., 2., 3., 4., 5.])
# is_track: True
# orig_shape: (720, 1280)
# shape: torch.Size([5, 7])
# xywh: tensor([[ 826.9961,  290.0563,   45.8259,   38.2595],
#         [ 678.5566,  487.7337,   39.5220,   35.9261],
#         [ 915.0060,  369.9839,   35.4943,   32.2847],
#         [ 615.6565,  395.6085,   41.2144,   33.6360],
#         [1012.9664,  459.5880,   42.2214,   38.8322]])
# xywhn: tensor([[0.6461, 0.4029, 0.0358, 0.0531],
#         [0.5301, 0.6774, 0.0309, 0.0499],
#         [0.7148, 0.5139, 0.0277, 0.0448],
#         [0.4810, 0.5495, 0.0322, 0.0467],
#         [0.7914, 0.6383, 0.0330, 0.0539]])
# xyxy: tensor([[ 804.0831,  270.9266,  849.9091,  309.1861],
#         [ 658.7957,  469.7707,  698.3176,  505.6968],
#         [ 897.2589,  353.8416,  932.7531,  386.1262],
#         [ 595.0493,  378.7905,  636.2637,  412.4265],
#         [ 991.8557,  440.1719, 1034.0771,  479.0042]])
# xyxyn: tensor([[0.6282, 0.3763, 0.6640, 0.4294],
#         [0.5147, 0.6525, 0.5456, 0.7024],
#         [0.7010, 0.4914, 0.7287, 0.5363],
#         [0.4649, 0.5261, 0.4971, 0.5728],
#         [0.7749, 0.6113, 0.8079, 0.6653]])
# video 1/1 (8/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 238.8ms
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0., 2., 2., 2., 2.])
# conf: tensor([0.7593, 0.7351, 0.7212, 0.7165, 0.7086])
# data: tensor([[8.0405e+02, 2.7091e+02, 8.4993e+02, 3.0924e+02, 1.0000e+00, 7.5925e-01, 0.0000e+00],
#         [6.5864e+02, 4.6966e+02, 6.9832e+02, 5.0575e+02, 2.0000e+00, 7.3511e-01, 2.0000e+00],
#         [5.9463e+02, 3.7710e+02, 6.3625e+02, 4.1190e+02, 3.0000e+00, 7.2124e-01, 2.0000e+00],
#         [8.9726e+02, 3.5383e+02, 9.3274e+02, 3.8611e+02, 4.0000e+00, 7.1648e-01, 2.0000e+00],
#         [9.9185e+02, 4.4019e+02, 1.0340e+03, 4.7901e+02, 5.0000e+00, 7.0861e-01, 2.0000e+00]])
# id: tensor([1., 2., 3., 4., 5.])
# is_track: True
# orig_shape: (720, 1280)
# shape: torch.Size([5, 7])
# xywh: tensor([[ 826.9885,  290.0750,   45.8782,   38.3377],
#         [ 678.4806,  487.7045,   39.6799,   36.0974],
#         [ 615.4380,  394.4992,   41.6191,   34.7932],
#         [ 915.0029,  369.9691,   35.4834,   32.2743],
#         [1012.9303,  459.5974,   42.1580,   38.8156]])
# xywhn: tensor([[0.6461, 0.4029, 0.0358, 0.0532],
#         [0.5301, 0.6774, 0.0310, 0.0501],
#         [0.4808, 0.5479, 0.0325, 0.0483],
#         [0.7148, 0.5138, 0.0277, 0.0448],
#         [0.7914, 0.6383, 0.0329, 0.0539]])
# xyxy: tensor([[ 804.0494,  270.9061,  849.9276,  309.2438],
#         [ 658.6406,  469.6558,  698.3206,  505.7532],
#         [ 594.6285,  377.1026,  636.2476,  411.8958],
#         [ 897.2612,  353.8319,  932.7446,  386.1062],
#         [ 991.8513,  440.1896, 1034.0093,  479.0051]])
# xyxyn: tensor([[0.6282, 0.3763, 0.6640, 0.4295],
#         [0.5146, 0.6523, 0.5456, 0.7024],
#         [0.4646, 0.5238, 0.4971, 0.5721],
#         [0.7010, 0.4914, 0.7287, 0.5363],
#         [0.7749, 0.6114, 0.8078, 0.6653]])
# video 1/1 (9/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 248.6ms
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0., 2., 2., 2., 2.])
# conf: tensor([0.7599, 0.7358, 0.7250, 0.7172, 0.7084])
# data: tensor([[8.0407e+02, 2.7089e+02, 8.4986e+02, 3.0929e+02, 1.0000e+00, 7.5994e-01, 0.0000e+00],
#         [6.5866e+02, 4.6974e+02, 6.9842e+02, 5.0578e+02, 2.0000e+00, 7.3578e-01, 2.0000e+00],
#         [5.9451e+02, 3.7652e+02, 6.3656e+02, 4.1209e+02, 3.0000e+00, 7.2499e-01, 2.0000e+00],
#         [8.9720e+02, 3.5378e+02, 9.3276e+02, 3.8611e+02, 4.0000e+00, 7.1717e-01, 2.0000e+00],
#         [9.9175e+02, 4.4011e+02, 1.0341e+03, 4.7908e+02, 5.0000e+00, 7.0838e-01, 2.0000e+00]])
# id: tensor([1., 2., 3., 4., 5.])
# is_track: True
# orig_shape: (720, 1280)
# shape: torch.Size([5, 7])
# xywh: tensor([[ 826.9648,  290.0906,   45.7954,   38.4001],
#         [ 678.5427,  487.7644,   39.7571,   36.0400],
#         [ 615.5321,  394.3087,   42.0493,   35.5715],
#         [ 914.9825,  369.9460,   35.5579,   32.3299],
#         [1012.9197,  459.5953,   42.3374,   38.9716]])
# xywhn: tensor([[0.6461, 0.4029, 0.0358, 0.0533],
#         [0.5301, 0.6775, 0.0311, 0.0501],
#         [0.4809, 0.5477, 0.0329, 0.0494],
#         [0.7148, 0.5138, 0.0278, 0.0449],
#         [0.7913, 0.6383, 0.0331, 0.0541]])
# xyxy: tensor([[ 804.0671,  270.8906,  849.8625,  309.2907],
#         [ 658.6642,  469.7444,  698.4213,  505.7844],
#         [ 594.5074,  376.5229,  636.5568,  412.0945],
#         [ 897.2036,  353.7811,  932.7614,  386.1110],
#         [ 991.7510,  440.1095, 1034.0884,  479.0811]])
# xyxyn: tensor([[0.6282, 0.3762, 0.6640, 0.4296],
#         [0.5146, 0.6524, 0.5456, 0.7025],
#         [0.4645, 0.5229, 0.4973, 0.5724],
#         [0.7009, 0.4914, 0.7287, 0.5363],
#         [0.7748, 0.6113, 0.8079, 0.6654]])
# video 1/1 (10/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 237.1ms
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0., 2., 2., 2., 2.])
# conf: tensor([0.7590, 0.7361, 0.7282, 0.7172, 0.7071])
# data: tensor([[8.0409e+02, 2.7099e+02, 8.4989e+02, 3.0942e+02, 1.0000e+00, 7.5903e-01, 0.0000e+00],
#         [6.5870e+02, 4.6970e+02, 6.9863e+02, 5.0581e+02, 2.0000e+00, 7.3606e-01, 2.0000e+00],
#         [5.9497e+02, 3.7642e+02, 6.3659e+02, 4.1251e+02, 3.0000e+00, 7.2819e-01, 2.0000e+00],
#         [8.9714e+02, 3.5380e+02, 9.3276e+02, 3.8614e+02, 4.0000e+00, 7.1723e-01, 2.0000e+00],
#         [9.9182e+02, 4.4017e+02, 1.0341e+03, 4.7906e+02, 5.0000e+00, 7.0709e-01, 2.0000e+00]])
# id: tensor([1., 2., 3., 4., 5.])
# is_track: True
# orig_shape: (720, 1280)
# shape: torch.Size([5, 7])
# xywh: tensor([[ 826.9894,  290.2027,   45.7981,   38.4293],
#         [ 678.6680,  487.7522,   39.9299,   36.1125],
#         [ 615.7773,  394.4650,   41.6199,   36.0887],
#         [ 914.9536,  369.9666,   35.6226,   32.3430],
#         [1012.9654,  459.6167,   42.2953,   38.8915]])
# xywhn: tensor([[0.6461, 0.4031, 0.0358, 0.0534],
#         [0.5302, 0.6774, 0.0312, 0.0502],
#         [0.4811, 0.5479, 0.0325, 0.0501],
#         [0.7148, 0.5138, 0.0278, 0.0449],
#         [0.7914, 0.6384, 0.0330, 0.0540]])
# xyxy: tensor([[ 804.0903,  270.9880,  849.8884,  309.4173],
#         [ 658.7030,  469.6959,  698.6329,  505.8084],
#         [ 594.9674,  376.4206,  636.5873,  412.5093],
#         [ 897.1423,  353.7951,  932.7648,  386.1380],
#         [ 991.8177,  440.1709, 1034.1130,  479.0624]])
# xyxyn: tensor([[0.6282, 0.3764, 0.6640, 0.4297],
#         [0.5146, 0.6524, 0.5458, 0.7025],
#         [0.4648, 0.5228, 0.4973, 0.5729],
#         [0.7009, 0.4914, 0.7287, 0.5363],
#         [0.7749, 0.6113, 0.8079, 0.6654]])
# video 1/1 (11/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 234.6ms
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0., 2., 2., 2., 2.])
# conf: tensor([0.7629, 0.7355, 0.7302, 0.7196, 0.7063])
# data: tensor([[8.0447e+02, 2.7128e+02, 8.4994e+02, 3.0931e+02, 1.0000e+00, 7.6294e-01, 0.0000e+00],
#         [6.5894e+02, 4.6978e+02, 6.9884e+02, 5.0576e+02, 2.0000e+00, 7.3545e-01, 2.0000e+00],
#         [5.9526e+02, 3.7611e+02, 6.3699e+02, 4.1210e+02, 3.0000e+00, 7.3016e-01, 2.0000e+00],
#         [8.9697e+02, 3.5378e+02, 9.3241e+02, 3.8603e+02, 4.0000e+00, 7.1959e-01, 2.0000e+00],
#         [9.9191e+02, 4.4024e+02, 1.0341e+03, 4.7899e+02, 5.0000e+00, 7.0626e-01, 2.0000e+00]])
# id: tensor([1., 2., 3., 4., 5.])
# is_track: True
# orig_shape: (720, 1280)
# shape: torch.Size([5, 7])
# xywh: tensor([[ 827.2069,  290.2952,   45.4727,   38.0383],
#         [ 678.8878,  487.7728,   39.8989,   35.9797],
#         [ 616.1249,  394.1056,   41.7246,   35.9855],
#         [ 914.6901,  369.9029,   35.4376,   32.2533],
#         [1012.9867,  459.6119,   42.1597,   38.7532]])
# xywhn: tensor([[0.6463, 0.4032, 0.0355, 0.0528],
#         [0.5304, 0.6775, 0.0312, 0.0500],
#         [0.4813, 0.5474, 0.0326, 0.0500],
#         [0.7146, 0.5138, 0.0277, 0.0448],
#         [0.7914, 0.6383, 0.0329, 0.0538]])
# xyxy: tensor([[ 804.4706,  271.2761,  849.9432,  309.3144],
#         [ 658.9384,  469.7830,  698.8373,  505.7627],
#         [ 595.2626,  376.1129,  636.9872,  412.0983],
#         [ 896.9713,  353.7762,  932.4089,  386.0295],
#         [ 991.9069,  440.2353, 1034.0665,  478.9885]])
# xyxyn: tensor([[0.6285, 0.3768, 0.6640, 0.4296],
#         [0.5148, 0.6525, 0.5460, 0.7024],
#         [0.4650, 0.5224, 0.4976, 0.5724],
#         [0.7008, 0.4914, 0.7284, 0.5362],
#         [0.7749, 0.6114, 0.8079, 0.6653]])
# video 1/1 (12/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 251.4ms
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0., 2., 2., 2., 2., 3.])
# conf: tensor([0.7635, 0.7357, 0.7326, 0.7213, 0.7069, 0.6048])
# data: tensor([[8.0447e+02, 2.7123e+02, 8.5000e+02, 3.0933e+02, 1.0000e+00, 7.6345e-01, 0.0000e+00],
#         [6.5921e+02, 4.6982e+02, 6.9887e+02, 5.0580e+02, 2.0000e+00, 7.3568e-01, 2.0000e+00],
#         [5.9607e+02, 3.7709e+02, 6.3825e+02, 4.1234e+02, 3.0000e+00, 7.3261e-01, 2.0000e+00],
#         [8.9704e+02, 3.5381e+02, 9.3236e+02, 3.8595e+02, 4.0000e+00, 7.2127e-01, 2.0000e+00],
#         [9.9206e+02, 4.4032e+02, 1.0340e+03, 4.7889e+02, 5.0000e+00, 7.0695e-01, 2.0000e+00],
#         [3.8759e+02, 2.9582e+02, 4.2034e+02, 3.3923e+02, 6.0000e+00, 6.0479e-01, 3.0000e+00]])
# id: tensor([1., 2., 3., 4., 5., 6.])
# is_track: True
# orig_shape: (720, 1280)
# shape: torch.Size([6, 7])
# xywh: tensor([[ 827.2343,  290.2830,   45.5251,   38.0970],
#         [ 679.0400,  487.8110,   39.6675,   35.9875],
#         [ 617.1580,  394.7130,   42.1753,   35.2468],
#         [ 914.6970,  369.8802,   35.3197,   32.1423],
#         [1013.0254,  459.6023,   41.9221,   38.5720],
#         [ 403.9605,  317.5256,   32.7491,   43.4174]])
# xywhn: tensor([[0.6463, 0.4032, 0.0356, 0.0529],
#         [0.5305, 0.6775, 0.0310, 0.0500],
#         [0.4822, 0.5482, 0.0329, 0.0490],
#         [0.7146, 0.5137, 0.0276, 0.0446],
#         [0.7914, 0.6383, 0.0328, 0.0536],
#         [0.3156, 0.4410, 0.0256, 0.0603]])
# xyxy: tensor([[ 804.4717,  271.2345,  849.9968,  309.3315],
#         [ 659.2063,  469.8173,  698.8738,  505.8048],
#         [ 596.0703,  377.0895,  638.2456,  412.3364],
#         [ 897.0371,  353.8090,  932.3568,  385.9514],
#         [ 992.0643,  440.3163, 1033.9865,  478.8883],
#         [ 387.5859,  295.8169,  420.3351,  339.2343]])
# xyxyn: tensor([[0.6285, 0.3767, 0.6641, 0.4296],
#         [0.5150, 0.6525, 0.5460, 0.7025],
#         [0.4657, 0.5237, 0.4986, 0.5727],
#         [0.7008, 0.4914, 0.7284, 0.5360],
#         [0.7751, 0.6116, 0.8078, 0.6651],
#         [0.3028, 0.4109, 0.3284, 0.4712]])
# video 1/1 (13/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 250.1ms
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0., 2., 2., 2., 2.])
# conf: tensor([0.7640, 0.7367, 0.7218, 0.7188, 0.7064])
# data: tensor([[8.0447e+02, 2.7135e+02, 8.4991e+02, 3.0916e+02, 1.0000e+00, 7.6397e-01, 0.0000e+00],
#         [6.5917e+02, 4.6972e+02, 6.9837e+02, 5.0578e+02, 2.0000e+00, 7.3669e-01, 2.0000e+00],
#         [5.9729e+02, 3.7980e+02, 6.3815e+02, 4.1269e+02, 3.0000e+00, 7.2184e-01, 2.0000e+00],
#         [8.9690e+02, 3.5384e+02, 9.3230e+02, 3.8598e+02, 4.0000e+00, 7.1876e-01, 2.0000e+00],
#         [9.9200e+02, 4.4033e+02, 1.0340e+03, 4.7888e+02, 5.0000e+00, 7.0639e-01, 2.0000e+00]])
# id: tensor([1., 2., 3., 4., 5.])
# is_track: True
# orig_shape: (720, 1280)
# shape: torch.Size([5, 7])
# xywh: tensor([[ 827.1918,  290.2551,   45.4362,   37.8074],
#         [ 678.7695,  487.7494,   39.1921,   36.0575],
#         [ 617.7166,  396.2449,   40.8584,   32.8925],
#         [ 914.5963,  369.9098,   35.4023,   32.1414],
#         [1012.9910,  459.6047,   41.9871,   38.5493]])
# xywhn: tensor([[0.6462, 0.4031, 0.0355, 0.0525],
#         [0.5303, 0.6774, 0.0306, 0.0501],
#         [0.4826, 0.5503, 0.0319, 0.0457],
#         [0.7145, 0.5138, 0.0277, 0.0446],
#         [0.7914, 0.6383, 0.0328, 0.0535]])
# xyxy: tensor([[ 804.4738,  271.3514,  849.9099,  309.1588],
#         [ 659.1735,  469.7206,  698.3656,  505.7781],
#         [ 597.2874,  379.7987,  638.1458,  412.6912],
#         [ 896.8951,  353.8391,  932.2975,  385.9805],
#         [ 991.9974,  440.3301, 1033.9845,  478.8794]])
# xyxyn: tensor([[0.6285, 0.3769, 0.6640, 0.4294],
#         [0.5150, 0.6524, 0.5456, 0.7025],
#         [0.4666, 0.5275, 0.4986, 0.5732],
#         [0.7007, 0.4914, 0.7284, 0.5361],
#         [0.7750, 0.6116, 0.8078, 0.6651]])
# video 1/1 (14/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 236.9ms
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([3., 0., 2., 2., 2., 2.])
# conf: tensor([0.7684, 0.7599, 0.7330, 0.7261, 0.7173, 0.7026])
# data: tensor([[4.0411e+02, 2.9856e+02, 4.3479e+02, 3.3668e+02, 1.0000e+00, 7.6839e-01, 3.0000e+00],
#         [8.0424e+02, 2.7154e+02, 8.5004e+02, 3.0877e+02, 2.0000e+00, 7.5989e-01, 0.0000e+00],
#         [6.5902e+02, 4.6971e+02, 6.9807e+02, 5.0574e+02, 3.0000e+00, 7.3301e-01, 2.0000e+00],
#         [5.9741e+02, 3.8052e+02, 6.3896e+02, 4.1295e+02, 4.0000e+00, 7.2607e-01, 2.0000e+00],
#         [8.9723e+02, 3.5373e+02, 9.3286e+02, 3.8593e+02, 5.0000e+00, 7.1731e-01, 2.0000e+00],
#         [9.9259e+02, 4.4040e+02, 1.0345e+03, 4.7886e+02, 6.0000e+00, 7.0259e-01, 2.0000e+00]])
# id: tensor([1., 2., 3., 4., 5., 6.])
# is_track: True
# orig_shape: (720, 1280)
# shape: torch.Size([6, 7])
# xywh: tensor([[ 419.4471,  317.6207,   30.6826,   38.1191],
#         [ 827.1401,  290.1537,   45.8060,   37.2254],
#         [ 678.5460,  487.7251,   39.0530,   36.0357],
#         [ 618.1838,  396.7376,   41.5476,   32.4316],
#         [ 915.0471,  369.8308,   35.6351,   32.2017],
#         [1013.5366,  459.6265,   41.8899,   38.4591]])
# xywhn: tensor([[0.3277, 0.4411, 0.0240, 0.0529],
#         [0.6462, 0.4030, 0.0358, 0.0517],
#         [0.5301, 0.6774, 0.0305, 0.0500],
#         [0.4830, 0.5510, 0.0325, 0.0450],
#         [0.7149, 0.5137, 0.0278, 0.0447],
#         [0.7918, 0.6384, 0.0327, 0.0534]])
# xyxy: tensor([[ 404.1058,  298.5612,  434.7884,  336.6803],
#         [ 804.2371,  271.5410,  850.0432,  308.7664],
#         [ 659.0195,  469.7073,  698.0725,  505.7430],
#         [ 597.4100,  380.5218,  638.9576,  412.9534],
#         [ 897.2296,  353.7300,  932.8647,  385.9316],
#         [ 992.5917,  440.3969, 1034.4816,  478.8560]])
# xyxyn: tensor([[0.3157, 0.4147, 0.3397, 0.4676],
#         [0.6283, 0.3771, 0.6641, 0.4288],
#         [0.5149, 0.6524, 0.5454, 0.7024],
#         [0.4667, 0.5285, 0.4992, 0.5735],
#         [0.7010, 0.4913, 0.7288, 0.5360],
#         [0.7755, 0.6117, 0.8082, 0.6651]])
# video 1/1 (15/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 239.3ms
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([3., 0., 2., 2., 2., 2.])
# conf: tensor([0.7818, 0.7601, 0.7306, 0.7194, 0.7191, 0.7013])
# data: tensor([[4.0204e+02, 2.9991e+02, 4.3349e+02, 3.3703e+02, 1.0000e+00, 7.8181e-01, 3.0000e+00],
#         [8.0445e+02, 2.7159e+02, 8.5008e+02, 3.0884e+02, 2.0000e+00, 7.6011e-01, 0.0000e+00],
#         [6.5918e+02, 4.6967e+02, 6.9823e+02, 5.0571e+02, 3.0000e+00, 7.3064e-01, 2.0000e+00],
#         [5.9826e+02, 3.8100e+02, 6.4054e+02, 4.1206e+02, 4.0000e+00, 7.1940e-01, 2.0000e+00],
#         [8.9690e+02, 3.5378e+02, 9.3276e+02, 3.8610e+02, 5.0000e+00, 7.1907e-01, 2.0000e+00],
#         [9.9270e+02, 4.4045e+02, 1.0344e+03, 4.7881e+02, 6.0000e+00, 7.0125e-01, 2.0000e+00]])
# id: tensor([1., 2., 3., 4., 5., 6.])
# is_track: True
# orig_shape: (720, 1280)
# shape: torch.Size([6, 7])
# xywh: tensor([[ 417.7629,  318.4695,   31.4520,   37.1111],
#         [ 827.2645,  290.2153,   45.6338,   37.2445],
#         [ 678.7042,  487.6912,   39.0457,   36.0464],
#         [ 619.4021,  396.5326,   42.2788,   31.0645],
#         [ 914.8278,  369.9393,   35.8618,   32.3157],
#         [1013.5745,  459.6309,   41.7454,   38.3674]])
# xywhn: tensor([[0.3264, 0.4423, 0.0246, 0.0515],
#         [0.6463, 0.4031, 0.0357, 0.0517],
#         [0.5302, 0.6773, 0.0305, 0.0501],
#         [0.4839, 0.5507, 0.0330, 0.0431],
#         [0.7147, 0.5138, 0.0280, 0.0449],
#         [0.7919, 0.6384, 0.0326, 0.0533]])
# xyxy: tensor([[ 402.0369,  299.9139,  433.4890,  337.0250],
#         [ 804.4476,  271.5931,  850.0814,  308.8376],
#         [ 659.1814,  469.6680,  698.2271,  505.7144],
#         [ 598.2627,  381.0003,  640.5415,  412.0648],
#         [ 896.8969,  353.7814,  932.7587,  386.0972],
#         [ 992.7018,  440.4471, 1034.4471,  478.8146]])
# xyxyn: tensor([[0.3141, 0.4165, 0.3387, 0.4681],
#         [0.6285, 0.3772, 0.6641, 0.4289],
#         [0.5150, 0.6523, 0.5455, 0.7024],
#         [0.4674, 0.5292, 0.5004, 0.5723],
#         [0.7007, 0.4914, 0.7287, 0.5362],
#         [0.7755, 0.6117, 0.8082, 0.6650]])
# video 1/1 (16/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 234.8ms
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([3., 0., 2., 2., 2., 2.])
# conf: tensor([0.7753, 0.7594, 0.7316, 0.7271, 0.7156, 0.7018])
# data: tensor([[4.0246e+02, 3.0058e+02, 4.3215e+02, 3.3706e+02, 1.0000e+00, 7.7525e-01, 3.0000e+00],
#         [8.0435e+02, 2.7163e+02, 8.5022e+02, 3.0881e+02, 2.0000e+00, 7.5944e-01, 0.0000e+00],
#         [5.9818e+02, 3.7934e+02, 6.3922e+02, 4.1245e+02, 3.0000e+00, 7.3158e-01, 2.0000e+00],
#         [6.5918e+02, 4.6968e+02, 6.9819e+02, 5.0571e+02, 4.0000e+00, 7.2710e-01, 2.0000e+00],
#         [8.9708e+02, 3.5382e+02, 9.3318e+02, 3.8619e+02, 5.0000e+00, 7.1556e-01, 2.0000e+00],
#         [9.9284e+02, 4.4040e+02, 1.0345e+03, 4.7874e+02, 6.0000e+00, 7.0184e-01, 2.0000e+00]])
# id: tensor([1., 2., 3., 4., 5., 6.])
# is_track: True
# orig_shape: (720, 1280)
# shape: torch.Size([6, 7])
# xywh: tensor([[ 417.3037,  318.8181,   29.6939,   36.4783],
#         [ 827.2841,  290.2162,   45.8621,   37.1799],
#         [ 618.7008,  395.8915,   41.0345,   33.1094],
#         [ 678.6819,  487.6959,   39.0110,   36.0276],
#         [ 915.1288,  370.0073,   36.1008,   32.3676],
#         [1013.6706,  459.5715,   41.6666,   38.3374]])
# xywhn: tensor([[0.3260, 0.4428, 0.0232, 0.0507],
#         [0.6463, 0.4031, 0.0358, 0.0516],
#         [0.4834, 0.5498, 0.0321, 0.0460],
#         [0.5302, 0.6774, 0.0305, 0.0500],
#         [0.7149, 0.5139, 0.0282, 0.0450],
#         [0.7919, 0.6383, 0.0326, 0.0532]])
# xyxy: tensor([[ 402.4568,  300.5789,  432.1507,  337.0572],
#         [ 804.3530,  271.6263,  850.2151,  308.8062],
#         [ 598.1835,  379.3369,  639.2181,  412.4462],
#         [ 659.1764,  469.6821,  698.1874,  505.7097],
#         [ 897.0784,  353.8235,  933.1792,  386.1911],
#         [ 992.8373,  440.4028, 1034.5039,  478.7402]])
# xyxyn: tensor([[0.3144, 0.4175, 0.3376, 0.4681],
#         [0.6284, 0.3773, 0.6642, 0.4289],
#         [0.4673, 0.5269, 0.4994, 0.5728],
#         [0.5150, 0.6523, 0.5455, 0.7024],
#         [0.7008, 0.4914, 0.7290, 0.5364],
#         [0.7757, 0.6117, 0.8082, 0.6649]])
# video 1/1 (17/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 234.3ms
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([3., 0., 2., 2., 2., 2.])
# conf: tensor([0.7777, 0.7593, 0.7349, 0.7241, 0.7069, 0.7012])
# data: tensor([[4.0272e+02, 2.9978e+02, 4.3233e+02, 3.3709e+02, 1.0000e+00, 7.7772e-01, 3.0000e+00],
#         [8.0449e+02, 2.7174e+02, 8.5022e+02, 3.0868e+02, 2.0000e+00, 7.5935e-01, 0.0000e+00],
#         [5.9758e+02, 3.7811e+02, 6.3920e+02, 4.1171e+02, 3.0000e+00, 7.3486e-01, 2.0000e+00],
#         [6.5957e+02, 4.7003e+02, 6.9886e+02, 5.0547e+02, 4.0000e+00, 7.2413e-01, 2.0000e+00],
#         [8.9730e+02, 3.5381e+02, 9.3380e+02, 3.8630e+02, 5.0000e+00, 7.0691e-01, 2.0000e+00],
#         [9.9302e+02, 4.4030e+02, 1.0349e+03, 4.7883e+02, 6.0000e+00, 7.0118e-01, 2.0000e+00]])
# id: tensor([1., 2., 3., 4., 5., 6.])
# is_track: True
# orig_shape: (720, 1280)
# shape: torch.Size([6, 7])
# xywh: tensor([[ 417.5250,  318.4343,   29.6194,   37.3018],
#         [ 827.3572,  290.2088,   45.7290,   36.9468],
#         [ 618.3909,  394.9098,   41.6257,   33.6090],
#         [ 679.2139,  487.7522,   39.2827,   35.4368],
#         [ 915.5507,  370.0541,   36.4923,   32.4940],
#         [1013.9409,  459.5671,   41.8389,   38.5316]])
# xywhn: tensor([[0.3262, 0.4423, 0.0231, 0.0518],
#         [0.6464, 0.4031, 0.0357, 0.0513],
#         [0.4831, 0.5485, 0.0325, 0.0467],
#         [0.5306, 0.6774, 0.0307, 0.0492],
#         [0.7153, 0.5140, 0.0285, 0.0451],
#         [0.7921, 0.6383, 0.0327, 0.0535]])
# xyxy: tensor([[ 402.7153,  299.7834,  432.3347,  337.0851],
#         [ 804.4927,  271.7354,  850.2217,  308.6822],
#         [ 597.5781,  378.1053,  639.2038,  411.7143],
#         [ 659.5725,  470.0338,  698.8552,  505.4706],
#         [ 897.3046,  353.8071,  933.7969,  386.3011],
#         [ 993.0215,  440.3013, 1034.8604,  478.8329]])
# xyxyn: tensor([[0.3146, 0.4164, 0.3378, 0.4682],
#         [0.6285, 0.3774, 0.6642, 0.4287],
#         [0.4669, 0.5251, 0.4994, 0.5718],
#         [0.5153, 0.6528, 0.5460, 0.7020],
#         [0.7010, 0.4914, 0.7295, 0.5365],
#         [0.7758, 0.6115, 0.8085, 0.6650]])
# video 1/1 (18/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 240.2ms
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([3., 0., 2., 2., 2., 2.])
# conf: tensor([0.7864, 0.7615, 0.7425, 0.7247, 0.7069, 0.6999])
# data: tensor([[4.0250e+02, 2.9919e+02, 4.3279e+02, 3.3709e+02, 1.0000e+00, 7.8638e-01, 3.0000e+00],
#         [8.0464e+02, 2.7169e+02, 8.5043e+02, 3.0877e+02, 2.0000e+00, 7.6147e-01, 0.0000e+00],
#         [5.9848e+02, 3.7925e+02, 6.3759e+02, 4.1172e+02, 3.0000e+00, 7.4249e-01, 2.0000e+00],
#         [6.5966e+02, 4.7012e+02, 6.9883e+02, 5.0535e+02, 4.0000e+00, 7.2468e-01, 2.0000e+00],
#         [8.9736e+02, 3.5391e+02, 9.3389e+02, 3.8635e+02, 5.0000e+00, 7.0689e-01, 2.0000e+00],
#         [9.9303e+02, 4.4028e+02, 1.0349e+03, 4.7880e+02, 6.0000e+00, 6.9987e-01, 2.0000e+00]])
# id: tensor([1., 2., 3., 4., 5., 6.])
# is_track: True
# orig_shape: (720, 1280)
# shape: torch.Size([6, 7])
# xywh: tensor([[ 417.6421,  318.1420,   30.2862,   37.9015],
#         [ 827.5344,  290.2282,   45.7952,   37.0860],
#         [ 618.0369,  395.4843,   39.1152,   32.4738],
#         [ 679.2437,  487.7344,   39.1653,   35.2388],
#         [ 915.6260,  370.1320,   36.5332,   32.4398],
#         [1013.9673,  459.5388,   41.8727,   38.5193]])
# xywhn: tensor([[0.3263, 0.4419, 0.0237, 0.0526],
#         [0.6465, 0.4031, 0.0358, 0.0515],
#         [0.4828, 0.5493, 0.0306, 0.0451],
#         [0.5307, 0.6774, 0.0306, 0.0489],
#         [0.7153, 0.5141, 0.0285, 0.0451],
#         [0.7922, 0.6382, 0.0327, 0.0535]])
# xyxy: tensor([[ 402.4990,  299.1913,  432.7852,  337.0928],
#         [ 804.6368,  271.6852,  850.4320,  308.7712],
#         [ 598.4792,  379.2474,  637.5945,  411.7211],
#         [ 659.6610,  470.1151,  698.8263,  505.3538],
#         [ 897.3594,  353.9121,  933.8926,  386.3519],
#         [ 993.0310,  440.2792, 1034.9037,  478.7985]])
# xyxyn: tensor([[0.3145, 0.4155, 0.3381, 0.4682],
#         [0.6286, 0.3773, 0.6644, 0.4288],
#         [0.4676, 0.5267, 0.4981, 0.5718],
#         [0.5154, 0.6529, 0.5460, 0.7019],
#         [0.7011, 0.4915, 0.7296, 0.5366],
#         [0.7758, 0.6115, 0.8085, 0.6650]])
# video 1/1 (19/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 236.2ms
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([3., 0., 2., 2., 2., 2.])
# conf: tensor([0.7940, 0.7633, 0.7330, 0.7247, 0.6999, 0.6990])
# data: tensor([[4.0349e+02, 2.9872e+02, 4.3348e+02, 3.3728e+02, 1.0000e+00, 7.9404e-01, 3.0000e+00],
#         [8.0485e+02, 2.7176e+02, 8.5073e+02, 3.0880e+02, 2.0000e+00, 7.6333e-01, 0.0000e+00],
#         [5.9883e+02, 3.8132e+02, 6.3820e+02, 4.1294e+02, 3.0000e+00, 7.3302e-01, 2.0000e+00],
#         [6.5989e+02, 4.7040e+02, 6.9896e+02, 5.0504e+02, 4.0000e+00, 7.2472e-01, 2.0000e+00],
#         [8.9767e+02, 3.5394e+02, 9.3427e+02, 3.8626e+02, 5.0000e+00, 6.9993e-01, 2.0000e+00],
#         [9.9313e+02, 4.4022e+02, 1.0351e+03, 4.7874e+02, 6.0000e+00, 6.9901e-01, 2.0000e+00]])
# id: tensor([1., 2., 3., 4., 5., 6.])
# is_track: True
# orig_shape: (720, 1280)
# shape: torch.Size([6, 7])
# xywh: tensor([[ 418.4858,  318.0024,   29.9969,   38.5638],
#         [ 827.7874,  290.2791,   45.8796,   37.0336],
#         [ 618.5148,  397.1292,   39.3735,   31.6245],
#         [ 679.4226,  487.7210,   39.0740,   34.6409],
#         [ 915.9684,  370.0961,   36.6057,   32.3197],
#         [1014.1353,  459.4790,   42.0059,   38.5234]])
# xywhn: tensor([[0.3269, 0.4417, 0.0234, 0.0536],
#         [0.6467, 0.4032, 0.0358, 0.0514],
#         [0.4832, 0.5516, 0.0308, 0.0439],
#         [0.5308, 0.6774, 0.0305, 0.0481],
#         [0.7156, 0.5140, 0.0286, 0.0449],
#         [0.7923, 0.6382, 0.0328, 0.0535]])
# xyxy: tensor([[ 403.4873,  298.7205,  433.4843,  337.2843],
#         [ 804.8475,  271.7624,  850.7272,  308.7959],
#         [ 598.8280,  381.3169,  638.2015,  412.9414],
#         [ 659.8856,  470.4005,  698.9596,  505.0414],
#         [ 897.6655,  353.9363,  934.2712,  386.2560],
#         [ 993.1323,  440.2173, 1035.1382,  478.7407]])
# xyxyn: tensor([[0.3152, 0.4149, 0.3387, 0.4685],
#         [0.6288, 0.3774, 0.6646, 0.4289],
#         [0.4678, 0.5296, 0.4986, 0.5735],
#         [0.5155, 0.6533, 0.5461, 0.7014],
#         [0.7013, 0.4916, 0.7299, 0.5365],
#         [0.7759, 0.6114, 0.8087, 0.6649]])
# video 1/1 (20/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 237.1ms
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([3., 0., 2., 2., 2., 2.])
# conf: tensor([0.8009, 0.7635, 0.7380, 0.7308, 0.6986, 0.6920])
# data: tensor([[4.0368e+02, 2.9830e+02, 4.3453e+02, 3.3742e+02, 1.0000e+00, 8.0085e-01, 3.0000e+00],
#         [8.0521e+02, 2.7177e+02, 8.5100e+02, 3.0872e+02, 2.0000e+00, 7.6348e-01, 0.0000e+00],
#         [5.9901e+02, 3.8001e+02, 6.3840e+02, 4.1331e+02, 3.0000e+00, 7.3797e-01, 2.0000e+00],
#         [6.6029e+02, 4.7030e+02, 6.9941e+02, 5.0506e+02, 4.0000e+00, 7.3077e-01, 2.0000e+00],
#         [9.9318e+02, 4.4018e+02, 1.0354e+03, 4.7880e+02, 5.0000e+00, 6.9864e-01, 2.0000e+00],
#         [8.9789e+02, 3.5401e+02, 9.3458e+02, 3.8630e+02, 6.0000e+00, 6.9204e-01, 2.0000e+00]])
# id: tensor([1., 2., 3., 4., 5., 6.])
# is_track: True
# orig_shape: (720, 1280)
# shape: torch.Size([6, 7])
# xywh: tensor([[ 419.1036,  317.8606,   30.8517,   39.1182],
#         [ 828.1071,  290.2462,   45.7896,   36.9446],
#         [ 618.7018,  396.6633,   39.3906,   33.2983],
#         [ 679.8530,  487.6797,   39.1189,   34.7664],
#         [1014.2971,  459.4875,   42.2332,   38.6169],
#         [ 916.2341,  370.1556,   36.6833,   32.2856]])
# xywhn: tensor([[0.3274, 0.4415, 0.0241, 0.0543],
#         [0.6470, 0.4031, 0.0358, 0.0513],
#         [0.4834, 0.5509, 0.0308, 0.0462],
#         [0.5311, 0.6773, 0.0306, 0.0483],
#         [0.7924, 0.6382, 0.0330, 0.0536],
#         [0.7158, 0.5141, 0.0287, 0.0448]])
# xyxy: tensor([[ 403.6777,  298.3015,  434.5294,  337.4197],
#         [ 805.2123,  271.7739,  851.0018,  308.7184],
#         [ 599.0065,  380.0141,  638.3971,  413.3124],
#         [ 660.2936,  470.2964,  699.4125,  505.0629],
#         [ 993.1805,  440.1791, 1035.4137,  478.7960],
#         [ 897.8925,  354.0128,  934.5758,  386.2984]])
# xyxyn: tensor([[0.3154, 0.4143, 0.3395, 0.4686],
#         [0.6291, 0.3775, 0.6648, 0.4288],
#         [0.4680, 0.5278, 0.4987, 0.5740],
#         [0.5159, 0.6532, 0.5464, 0.7015],
#         [0.7759, 0.6114, 0.8089, 0.6650],
#         [0.7015, 0.4917, 0.7301, 0.5365]])
# video 1/1 (21/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 240.2ms
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([3., 0., 2., 2., 2., 2.])
# conf: tensor([0.8013, 0.7603, 0.7459, 0.7255, 0.6974, 0.6937])
# data: tensor([[4.0351e+02, 2.9827e+02, 4.3471e+02, 3.3745e+02, 1.0000e+00, 8.0132e-01, 3.0000e+00],
#         [8.0494e+02, 2.7177e+02, 8.5083e+02, 3.0871e+02, 2.0000e+00, 7.6032e-01, 0.0000e+00],
#         [5.9874e+02, 3.7936e+02, 6.3750e+02, 4.1262e+02, 3.0000e+00, 7.4589e-01, 2.0000e+00],
#         [6.6038e+02, 4.7053e+02, 6.9934e+02, 5.0484e+02, 4.0000e+00, 7.2546e-01, 2.0000e+00],
#         [9.9309e+02, 4.4018e+02, 1.0356e+03, 4.7890e+02, 5.0000e+00, 6.9743e-01, 2.0000e+00],
#         [8.9821e+02, 3.5408e+02, 9.3467e+02, 3.8631e+02, 6.0000e+00, 6.9369e-01, 2.0000e+00]])
# id: tensor([1., 2., 3., 4., 5., 6.])
# is_track: True
# orig_shape: (720, 1280)
# shape: torch.Size([6, 7])
# xywh: tensor([[ 419.1094,  317.8581,   31.1930,   39.1757],
#         [ 827.8881,  290.2403,   45.8914,   36.9423],
#         [ 618.1177,  395.9903,   38.7620,   33.2573],
#         [ 679.8579,  487.6841,   38.9548,   34.3154],
#         [1014.3250,  459.5383,   42.4746,   38.7242],
#         [ 916.4374,  370.1921,   36.4565,   32.2336]])
# xywhn: tensor([[0.3274, 0.4415, 0.0244, 0.0544],
#         [0.6468, 0.4031, 0.0359, 0.0513],
#         [0.4829, 0.5500, 0.0303, 0.0462],
#         [0.5311, 0.6773, 0.0304, 0.0477],
#         [0.7924, 0.6382, 0.0332, 0.0538],
#         [0.7160, 0.5142, 0.0285, 0.0448]])
# xyxy: tensor([[ 403.5129,  298.2702,  434.7059,  337.4460],
#         [ 804.9424,  271.7692,  850.8337,  308.7114],
#         [ 598.7367,  379.3616,  637.4987,  412.6190],
#         [ 660.3805,  470.5264,  699.3353,  504.8418],
#         [ 993.0876,  440.1762, 1035.5623,  478.9005],
#         [ 898.2091,  354.0753,  934.6656,  386.3089]])
# xyxyn: tensor([[0.3152, 0.4143, 0.3396, 0.4687],
#         [0.6289, 0.3775, 0.6647, 0.4288],
#         [0.4678, 0.5269, 0.4980, 0.5731],
#         [0.5159, 0.6535, 0.5464, 0.7012],
#         [0.7758, 0.6114, 0.8090, 0.6651],
#         [0.7017, 0.4918, 0.7302, 0.5365]])
# video 1/1 (22/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 235.0ms
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([3., 0., 2., 2., 2., 2.])
# conf: tensor([0.8032, 0.7595, 0.7386, 0.7242, 0.6970, 0.6914])
# data: tensor([[4.0288e+02, 2.9818e+02, 4.3486e+02, 3.3745e+02, 1.0000e+00, 8.0315e-01, 3.0000e+00],
#         [8.0508e+02, 2.7177e+02, 8.5099e+02, 3.0860e+02, 2.0000e+00, 7.5948e-01, 0.0000e+00],
#         [5.9797e+02, 3.7880e+02, 6.3741e+02, 4.1172e+02, 3.0000e+00, 7.3862e-01, 2.0000e+00],
#         [6.6046e+02, 4.7045e+02, 6.9950e+02, 5.0482e+02, 4.0000e+00, 7.2425e-01, 2.0000e+00],
#         [9.9308e+02, 4.4013e+02, 1.0358e+03, 4.7892e+02, 5.0000e+00, 6.9700e-01, 2.0000e+00],
#         [8.9835e+02, 3.5408e+02, 9.3463e+02, 3.8628e+02, 6.0000e+00, 6.9139e-01, 2.0000e+00]])
# id: tensor([1., 2., 3., 4., 5., 6.])
# is_track: True
# orig_shape: (720, 1280)
# shape: torch.Size([6, 7])
# xywh: tensor([[ 418.8684,  317.8146,   31.9827,   39.2616],
#         [ 828.0347,  290.1857,   45.9128,   36.8229],
#         [ 617.6897,  395.2621,   39.4460,   32.9215],
#         [ 679.9783,  487.6361,   39.0369,   34.3770],
#         [1014.4312,  459.5252,   42.7009,   38.7855],
#         [ 916.4889,  370.1819,   36.2786,   32.2048]])
# xywhn: tensor([[0.3272, 0.4414, 0.0250, 0.0545],
#         [0.6469, 0.4030, 0.0359, 0.0511],
#         [0.4826, 0.5490, 0.0308, 0.0457],
#         [0.5312, 0.6773, 0.0305, 0.0477],
#         [0.7925, 0.6382, 0.0334, 0.0539],
#         [0.7160, 0.5141, 0.0283, 0.0447]])
# xyxy: tensor([[ 402.8771,  298.1838,  434.8597,  337.4454],
#         [ 805.0782,  271.7742,  850.9911,  308.5971],
#         [ 597.9667,  378.8013,  637.4127,  411.7228],
#         [ 660.4598,  470.4476,  699.4967,  504.8246],
#         [ 993.0807,  440.1325, 1035.7816,  478.9180],
#         [ 898.3496,  354.0795,  934.6282,  386.2843]])
# xyxyn: tensor([[0.3147, 0.4141, 0.3397, 0.4687],
#         [0.6290, 0.3775, 0.6648, 0.4286],
#         [0.4672, 0.5261, 0.4980, 0.5718],
#         [0.5160, 0.6534, 0.5465, 0.7011],
#         [0.7758, 0.6113, 0.8092, 0.6652],
#         [0.7018, 0.4918, 0.7302, 0.5365]])
# video 1/1 (23/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 233.9ms
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([3., 0., 2., 2., 2., 2.])
# conf: tensor([0.8035, 0.7618, 0.7233, 0.7209, 0.6959, 0.6900])
# data: tensor([[4.0249e+02, 2.9810e+02, 4.3467e+02, 3.3736e+02, 1.0000e+00, 8.0349e-01, 3.0000e+00],
#         [8.0531e+02, 2.7184e+02, 8.5104e+02, 3.0852e+02, 2.0000e+00, 7.6181e-01, 0.0000e+00],
#         [5.9801e+02, 3.8008e+02, 6.3685e+02, 4.1137e+02, 3.0000e+00, 7.2328e-01, 2.0000e+00],
#         [6.6030e+02, 4.7048e+02, 6.9946e+02, 5.0472e+02, 4.0000e+00, 7.2093e-01, 2.0000e+00],
#         [9.9329e+02, 4.4026e+02, 1.0359e+03, 4.7889e+02, 5.0000e+00, 6.9592e-01, 2.0000e+00],
#         [8.9857e+02, 3.5409e+02, 9.3469e+02, 3.8625e+02, 6.0000e+00, 6.9004e-01, 2.0000e+00]])
# id: tensor([1., 2., 3., 4., 5., 6.])
# is_track: True
# orig_shape: (720, 1280)
# shape: torch.Size([6, 7])
# xywh: tensor([[ 418.5818,  317.7294,   32.1743,   39.2513],
#         [ 828.1761,  290.1839,   45.7273,   36.6812],
#         [ 617.4276,  395.7239,   38.8403,   31.2878],
#         [ 679.8815,  487.6006,   39.1555,   34.2485],
#         [1014.5959,  459.5753,   42.6113,   38.6376],
#         [ 916.6298,  370.1702,   36.1249,   32.1541]])
# xywhn: tensor([[0.3270, 0.4413, 0.0251, 0.0545],
#         [0.6470, 0.4030, 0.0357, 0.0509],
#         [0.4824, 0.5496, 0.0303, 0.0435],
#         [0.5312, 0.6772, 0.0306, 0.0476],
#         [0.7927, 0.6383, 0.0333, 0.0537],
#         [0.7161, 0.5141, 0.0282, 0.0447]])
# xyxy: tensor([[ 402.4947,  298.1038,  434.6690,  337.3551],
#         [ 805.3125,  271.8433,  851.0398,  308.5245],
#         [ 598.0074,  380.0800,  636.8478,  411.3678],
#         [ 660.3037,  470.4764,  699.4592,  504.7249],
#         [ 993.2903,  440.2565, 1035.9016,  478.8941],
#         [ 898.5673,  354.0932,  934.6922,  386.2473]])
# xyxyn: tensor([[0.3144, 0.4140, 0.3396, 0.4685],
#         [0.6292, 0.3776, 0.6649, 0.4285],
#         [0.4672, 0.5279, 0.4975, 0.5713],
#         [0.5159, 0.6534, 0.5465, 0.7010],
#         [0.7760, 0.6115, 0.8093, 0.6651],
#         [0.7020, 0.4918, 0.7302, 0.5365]])
# video 1/1 (24/122) /Users/pandoks/Documents/beta-tracker/data/yolo/video.mp4: 384x640 1 Corner, 4 Paints, 1 Tick, 237.0ms
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([3., 0., 2., 2., 2., 2.])
# conf: tensor([0.8043, 0.7609, 0.7212, 0.7204, 0.6962, 0.6907])
# data: tensor([[4.0203e+02, 2.9809e+02, 4.3492e+02, 3.3731e+02, 1.0000e+00, 8.0430e-01, 3.0000e+00],
#         [8.0540e+02, 2.7198e+02, 8.5089e+02, 3.0845e+02, 2.0000e+00, 7.6089e-01, 0.0000e+00],
#         [5.9695e+02, 3.7855e+02, 6.3767e+02, 4.1074e+02, 3.0000e+00, 7.2117e-01, 2.0000e+00],
#         [6.6050e+02, 4.7049e+02, 6.9961e+02, 5.0470e+02, 4.0000e+00, 7.2042e-01, 2.0000e+00],
#         [9.9326e+02, 4.4022e+02, 1.0359e+03, 4.7891e+02, 5.0000e+00, 6.9622e-01, 2.0000e+00],
#         [8.9871e+02, 3.5411e+02, 9.3482e+02, 3.8624e+02, 6.0000e+00, 6.9074e-01, 2.0000e+00]])
# id: tensor([1., 2., 3., 4., 5., 6.])
# is_track: True
# orig_shape: (720, 1280)
# shape: torch.Size([6, 7])
# xywh: tensor([[ 418.4775,  317.6993,   32.8860,   39.2278],
#         [ 828.1487,  290.2165,   45.4919,   36.4693],
#         [ 617.3076,  394.6447,   40.7231,   32.1938],
#         [ 680.0548,  487.5977,   39.1011,   34.2107],
#         [1014.5663,  459.5664,   42.6184,   38.6941],
#         [ 916.7665,  370.1737,   36.1111,   32.1246]])
# xywhn: tensor([[0.3269, 0.4412, 0.0257, 0.0545],
#         [0.6470, 0.4031, 0.0355, 0.0507],
#         [0.4823, 0.5481, 0.0318, 0.0447],
#         [0.5313, 0.6772, 0.0305, 0.0475],
#         [0.7926, 0.6383, 0.0333, 0.0537],
#         [0.7162, 0.5141, 0.0282, 0.0446]])
# xyxy: tensor([[ 402.0345,  298.0854,  434.9206,  337.3132],
#         [ 805.4027,  271.9819,  850.8947,  308.4512],
#         [ 596.9460,  378.5479,  637.6692,  410.7416],
#         [ 660.5043,  470.4924,  699.6053,  504.7031],
#         [ 993.2571,  440.2194, 1035.8755,  478.9135],
#         [ 898.7109,  354.1114,  934.8220,  386.2360]])
# xyxyn: tensor([[0.3141, 0.4140, 0.3398, 0.4685],
#         [0.6292, 0.3778, 0.6648, 0.4284],
#         [0.4664, 0.5258, 0.4982, 0.5705],
#         [0.5160, 0.6535, 0.5466, 0.7010],
#         [0.7760, 0.6114, 0.8093, 0.6652],
#         [0.7021, 0.4918, 0.7303, 0.5364]])
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # Calculate Homography

# %% [markdown]
# ## Diagram Data

# %%
court_points = {
    "left_corner": (145, 130),
    "right_corner": (1355, 130),

    "left_tick": (655, 130),
    "right_tick": (1345, 130),

    "middle": (1000, 130),

    "left_paint": {
        "t_left": (145, 440),
        "t_right": (490, 440),
        "b_left": (145, 730),
        "b_right": (490, 730)
    },

    "right_paint": {
        "t_left": (1510, 440),
        "t_right": (1855, 440),
        "b_left": (1510, 730),
        "b_right": (1855, 730)
    }
}

# %% [markdown]
# ## Parse Results

# %%
def center(box):
    x, y, w, h, id, conf, cls = box
    x, y, w, h = int(x), int(y), int(w), int(h)
    return (x + int(w/2), y + int(h/2))

# %%
import collections

def parse(data):
    data = data.boxes.data
    labels = collections.defaultdict(list)
    for label in data:
        id = int(label[4])
        conf = label[5].item()
        label_class = classes[int(label[6])]
        labels[label_class].append((center(label), conf, id))
    return labels

# %%
def define_paint(corners):
    if len(corners) != 4:
        return None

    sorted_x_corners = sorted(corners, key=lambda x: x[0])
    left_corners = sorted_x_corners[:2]
    right_corners = sorted_x_corners[2:]

    sorted_left_y_corners = sorted(left_corners, key=lambda x: x[1])
    sorted_right_y_corners = sorted(right_corners, key=lambda x: x[1])
    return {
        "top_left": sorted_left_y_corners[0],
        "top_right": sorted_right_y_corners[0],
        "bottom_left": sorted_left_y_corners[1],
        "bottom_right": sorted_right_y_corners[1],
    }

print(define_paint([(678, 487), (617, 365), (915, 370), (1013, 459)]))
# Out:
# {'top_left': (617, 365), 'top_right': (915, 370), 'bottom_left': (678, 487), 'bottom_right': (1013, 459)}

# %% [markdown]
# Homography with only paint corner:
# minimum 3 points bc we can fill in the fourth
# 4 points optimal
#
# Has Corner and Tick:
# paint corners to the right are baseline (2 points optimal)
# to the left free throw
#
# Has Corner:

# %%
# Priority list in order: paint, corner, tick, middle
def homography(labels, threshold=0):
    paint = define_paint(labels["paint"])
    court_points = np.array([
        paint["top_left"],
        paint["top_right"],
        paint["bottom_right"],
        paint["bottom_left"]
    ], dtype="float32")

    diagram_points = np.array([
        court_points["right_paint"]["t_left"],
        court_points["right_paint"]["t_right"],
        court_points["right_paint"]["b_right"],
        court_points["right_paint"]["b_left"]
    ], dtype="float32")

    homography_matrix, status = cv2.findHomography(court_points, diagram_points)

    return homography_matrix

# %%
import cv2

# This function will be called whenever a mouse event happens
def click_event(event, x, y, flags, param):
    if event == cv2.EVENT_LBUTTONDOWN:  # Left mouse button click
        print(f'Coordinates: ({x}, {y})')
        font = cv2.FONT_HERSHEY_SIMPLEX
        cv2.putText(img, f'({x},{y})', (x, y), font, 0.5, (255, 0, 0), 2)
        cv2.imshow("image", img)

# Read the image
img = cv2.imread('predict3/white.png')  # Replace with your image path
cv2.imshow('image', img)

# Set mouse callback function for window
cv2.setMouseCallback('image', click_event)

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Coordinates: (932, 480)
# Coordinates: (1070, 649)
# Coordinates: (1498, 435)
# Coordinates: (1715, 594)
# Coordinates: (887, 460)
# Coordinates: (980, 502)
# Coordinates: (884, 499)
# Coordinates: (981, 456)
# Coordinates: (888, 465)
# Coordinates: (885, 467)
# Coordinates: (884, 467)
# Coordinates: (864, 459)
# Coordinates: (864, 449)
# Coordinates: (866, 436)
# Coordinates: (880, 423)
# Coordinates: (889, 475)
# Coordinates: (885, 481)
# Coordinates: (180, 193)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/pandoks/Documents/beta-tracker/homography.ipynb Cell 24 line 4
#       <a href='vscode-notebook-cell:/Users/pandoks/Documents/beta-tracker/homography.ipynb#X32sZmlsZQ%3D%3D?line=0'>1</a> import cv2
#       <a href='vscode-notebook-cell:/Users/pandoks/Documents/beta-tracker/homography.ipynb#X32sZmlsZQ%3D%3D?line=2'>3</a> # This function will be called whenever a mouse event happens
# ----> <a href='vscode-notebook-cell:/Users/pandoks/Documents/beta-tracker/homography.ipynb#X32sZmlsZQ%3D%3D?line=3'>4</a> def click_event(event, x, y, flags, param):
#       <a href='vscode-notebook-cell:/Users/pandoks/Documents/beta-tracker/homography.ipynb#X32sZmlsZQ%3D%3D?line=4'>5</a>     if event == cv2.EVENT_LBUTTONDOWN:  # Left mouse button click
#       <a href='vscode-notebook-cell:/Users/pandoks/Documents/beta-tracker/homography.ipynb#X32sZmlsZQ%3D%3D?line=5'>6</a>         print(f'Coordinates: ({x}, {y})')
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import cv2

# Load the image
image = cv2.imread('data/court.png')
# Check if the image is loaded successfully
if image is None:
    print("Error: Could not open image.")
    exit()

# Load the video
cap = cv2.VideoCapture('data/yolo/video.mp4')
# Check if the video is opened successfully
if not cap.isOpened():
    print("Error: Could not open video.")
    exit()

# Loop through each frame
while True:
    # Capture frame-by-frame
    ret, frame = cap.read()

    # If frame is read correctly ret is True
    if not ret:
        print("Can't receive frame (stream end?). Exiting ...")
        break

    # Resize the video frame to match the image width if necessary
    # You might need to resize the image as well if it's not the same width as the video frames
    frame_width = frame.shape[1]
    image_resized = cv2.resize(image, (frame_width, int(image.shape[0] * (frame_width / image.shape[1]))))

    # Concatenate the image and the frame
    combined_frame = cv2.vconcat([frame, image_resized])

    # Display the resulting frame
    cv2.imshow('frame', combined_frame)

    # Wait indefinitely for a key press
    if cv2.waitKey(0) & 0xFF == ord('q'):
        break

# When everything done, release the capture and close all windows
cap.release()
cv2.destroyAllWindows()
# Out:
# Can't receive frame (stream end?). Exiting ...
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
